# %% [markdown]
# # Video frame extraction
#
# - Extract a picture every 5 frames, and save the frame extraction results in the `data_picture` folder

# %%
import os
import cv2
import time
import datetime

def framing():
    input_path = './data/C3'
    output_path = './data_picture/C3'
    txt_path = output_path+'/log.txt'
    with open(txt_path, "a", encoding="utf-8") as fi:
        fi.write('\n AllVideosFullName \t Index \t Frame \t Picture\n')

    videos = os.listdir(input_path)
    videos.sort(key = lambda x: x[:-4])

    if len(videos) != 0:
        video_num = 0
        for each_video in videos:
            print('Video {} is running ...'.format(video_num))
            each_video_input = input_path+'/'+str(each_video)
            each_video_output_path = output_path+'/'+str(each_video[:-4])
            if not os.path.exists(each_video_output_path):
                os.mkdir(each_video_output_path)
            
            capture = cv2.VideoCapture(each_video_input)
            if capture.isOpened():
                real = True
            else:
                real = False

            frame_step = 5
            frame_num = 0
            picture_num = 0

            while real:
                real, frame = capture.read()
                if frame is None:
                    break
                else:
                    if(frame_num % frame_step == 0):
                        cv2.imwrite(each_video_output_path+'/'+str(each_video[:-4])+'_Frame'+str(frame_num)+'_Pic'+str(picture_num)+'.jpg',frame)
                        picture_num += 1
                    frame_num += 1
                    cv2.waitKey(1)

            video_num += 1
            with open(txt_path, "a", encoding="utf-8") as fi:
                fi.write('{} \t {} \t {} \t {}\n'.format(each_video[:-4], video_num, frame_num, picture_num ))
            capture.release()

        print('Running log has been saved here: '+txt_path)

    else:
        print('Empty Directory')


if __name__ == '__main__':
    start_time = time.clock()
    framing()
    end_time = time.clock()
    delta_time = datetime.timedelta(seconds = (end_time-start_time))
    print('Running time is: %s '%(delta_time))
# Out:
# /home/xuenhui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# Video 0 is running ...
# Video 1 is running ...
# Video 2 is running ...
# Video 3 is running ...
# Video 4 is running ...
# Video 5 is running ...
# Video 6 is running ...
# Video 7 is running ...
# Video 8 is running ...
# Video 9 is running ...
# Video 10 is running ...
# Video 11 is running ...
# Video 12 is running ...
# Video 13 is running ...
# Video 14 is running ...
# Video 15 is running ...
# Video 16 is running ...
# Video 17 is running ...
# Video 18 is running ...
# Video 19 is running ...
# Video 20 is running ...
# Video 21 is running ...
# Video 22 is running ...
# Video 23 is running ...
# Video 24 is running ...
# Video 25 is running ...
# Video 26 is running ...
# Video 27 is running ...
# Video 28 is running ...
# Video 29 is running ...
# Video 30 is running ...
# Video 31 is running ...
# Video 32 is running ...
# Video 33 is running ...
# Video 34 is running ...
# Video 35 is running ...
# Video 36 is running ...
# Video 37 is running ...
# Video 38 is running ...
# Video 39 is running ...
# Video 40 is running ...
# Video 41 is running ...
# Video 42 is running ...
# Video 43 is running ...
# Video 44 is running ...
# Video 45 is running ...
# Video 46 is running ...
# Video 47 is running ...
# Video 48 is running ...
# Video 49 is running ...
# Video 50 is running ...
# Video 51 is running ...
# Video 52 is running ...
# Video 53 is running ...
# Video 54 is running ...
# Video 55 is running ...
# Video 56 is running ...
# Video 57 is running ...
# Video 58 is running ...
# Video 59 is running ...
# Video 60 is running ...
# Video 61 is running ...
# Video 62 is running ...
# Video 63 is running ...
# Video 64 is running ...
# Video 65 is running ...
# Video 66 is running ...
# Video 67 is running ...
# Video 68 is running ...
# Video 69 is running ...
# Video 70 is running ...
# Video 71 is running ...
# Video 72 is running ...
# Video 73 is running ...
# Video 74 is running ...
# Video 75 is running ...
# Video 76 is running ...
# Video 77 is running ...
# Video 78 is running ...
# Video 79 is running ...
# Video 80 is running ...
# Video 81 is running ...
# Video 82 is running ...
# Video 83 is running ...
# Video 84 is running ...
# Video 85 is running ...
# Video 86 is running ...
# Video 87 is running ...
# Video 88 is running ...
# Video 89 is running ...
# Video 90 is running ...
# Video 91 is running ...
# Video 92 is running ...
# Video 93 is running ...
# Video 94 is running ...
# Video 95 is running ...
# Video 96 is running ...
# Video 97 is running ...
# Video 98 is running ...
# Video 99 is running ...
# Video 100 is running ...
# Video 101 is running ...
# Video 102 is running ...
# Video 103 is running ...
# Video 104 is running ...
# Video 105 is running ...
# Video 106 is running ...
# Video 107 is running ...
# Video 108 is running ...
# Video 109 is running ...
# Video 110 is running ...
# Video 111 is running ...
# Video 112 is running ...
# Video 113 is running ...
# Video 114 is running ...
# Video 115 is running ...
# Video 116 is running ...
# Video 117 is running ...
# Video 118 is running ...
# Video 119 is running ...
# Video 120 is running ...
# Video 121 is running ...
# Video 122 is running ...
# Video 123 is running ...
# Video 124 is running ...
# Video 125 is running ...
# Video 126 is running ...
# Video 127 is running ...
# Video 128 is running ...
# Video 129 is running ...
# Video 130 is running ...
# Video 131 is running ...
# Video 132 is running ...
# Video 133 is running ...
# Video 134 is running ...
# Video 135 is running ...
# Video 136 is running ...
# Video 137 is running ...
# Video 138 is running ...
# Video 139 is running ...
# Video 140 is running ...
# Video 141 is running ...
# Video 142 is running ...
# Video 143 is running ...
# Video 144 is running ...
# Video 145 is running ...
# Video 146 is running ...
# Video 147 is running ...
# Video 148 is running ...
# Video 149 is running ...
# Video 150 is running ...
# Video 151 is running ...
# Video 152 is running ...
# Video 153 is running ...
# Video 154 is running ...
# Video 155 is running ...
# Video 156 is running ...
# Video 157 is running ...
# Video 158 is running ...
# Video 159 is running ...
# Video 160 is running ...
# Video 161 is running ...
# Video 162 is running ...
# Video 163 is running ...
# Video 164 is running ...
# Video 165 is running ...
# Video 166 is running ...
# Video 167 is running ...
# Video 168 is running ...
# Video 169 is running ...
# Video 170 is running ...
# Video 171 is running ...
# Video 172 is running ...
# Video 173 is running ...
# Video 174 is running ...
# Video 175 is running ...
# Video 176 is running ...
# Video 177 is running ...
# Video 178 is running ...
# Video 179 is running ...
# Video 180 is running ...
# Video 181 is running ...
# Video 182 is running ...
# Video 183 is running ...
# Video 184 is running ...
# Video 185 is running ...
# Video 186 is running ...
# Video 187 is running ...
# Video 188 is running ...
# Video 189 is running ...
# Video 190 is running ...
# Video 191 is running ...
# Video 192 is running ...
# Video 193 is running ...
# Video 194 is running ...
# Video 195 is running ...
# Video 196 is running ...
# Video 197 is running ...
# Video 198 is running ...
# Video 199 is running ...
# Video 200 is running ...
# Video 201 is running ...
# Video 202 is running ...
# Video 203 is running ...
# Video 204 is running ...
# Video 205 is running ...
# Video 206 is running ...
# Video 207 is running ...
# Video 208 is running ...
# Video 209 is running ...
# Video 210 is running ...
# Video 211 is running ...
# Video 212 is running ...
# Video 213 is running ...
# Video 214 is running ...
# Video 215 is running ...
# Video 216 is running ...
# Video 217 is running ...
# Video 218 is running ...
# Video 219 is running ...
# Video 220 is running ...
# Video 221 is running ...
# Video 222 is running ...
# Video 223 is running ...
# Video 224 is running ...
# Video 225 is running ...
# Video 226 is running ...
# Video 227 is running ...
# Video 228 is running ...
# Video 229 is running ...
# Video 230 is running ...
# Video 231 is running ...
# Video 232 is running ...
# Video 233 is running ...
# Video 234 is running ...
# Video 235 is running ...
# Video 236 is running ...
# Video 237 is running ...
# Video 238 is running ...
# Video 239 is running ...
# Video 240 is running ...
# Video 241 is running ...
# Video 242 is running ...
# Video 243 is running ...
# Video 244 is running ...
# Video 245 is running ...
# Video 246 is running ...
# Video 247 is running ...
# Video 248 is running ...
# Video 249 is running ...
# Video 250 is running ...
# Video 251 is running ...
# Video 252 is running ...
# Video 253 is running ...
# Video 254 is running ...
# Video 255 is running ...
# Video 256 is running ...
# Video 257 is running ...
# Video 258 is running ...
# Video 259 is running ...
# Video 260 is running ...
# Video 261 is running ...
# Video 262 is running ...
# Video 263 is running ...
# Video 264 is running ...
# Video 265 is running ...
# Video 266 is running ...
# Video 267 is running ...
# Video 268 is running ...
# Video 269 is running ...
# Video 270 is running ...
# Video 271 is running ...
# Video 272 is running ...
# Video 273 is running ...
# Video 274 is running ...
# Video 275 is running ...
# Video 276 is running ...
# Video 277 is running ...
# Video 278 is running ...
# Video 279 is running ...
# Video 280 is running ...
# Video 281 is running ...
# Video 282 is running ...
# Video 283 is running ...
# Video 284 is running ...
# Video 285 is running ...
# Video 286 is running ...
# Video 287 is running ...
# Video 288 is running ...
# Video 289 is running ...
# Video 290 is running ...
# Video 291 is running ...
# Video 292 is running ...
# Video 293 is running ...
# Video 294 is running ...
# Video 295 is running ...
# Video 296 is running ...
# Video 297 is running ...
# Video 298 is running ...
# Video 299 is running ...
# Video 300 is running ...
# Video 301 is running ...
# Video 302 is running ...
# Video 303 is running ...
# Video 304 is running ...
# Video 305 is running ...
# Video 306 is running ...
# Video 307 is running ...
# Video 308 is running ...
# Video 309 is running ...
# Video 310 is running ...
# Video 311 is running ...
# Video 312 is running ...
# Video 313 is running ...
# Video 314 is running ...
# Video 315 is running ...
# Video 316 is running ...
# Video 317 is running ...
# Video 318 is running ...
# Video 319 is running ...
# Video 320 is running ...
# Video 321 is running ...
# Video 322 is running ...
# Video 323 is running ...
# Video 324 is running ...
# Video 325 is running ...
# Video 326 is running ...
# Video 327 is running ...
# Video 328 is running ...
# Video 329 is running ...
# Video 330 is running ...
# Video 331 is running ...
# Video 332 is running ...
# Video 333 is running ...
# Video 334 is running ...
# Video 335 is running ...
# Video 336 is running ...
# Video 337 is running ...
# Video 338 is running ...
# Video 339 is running ...
# Video 340 is running ...
# Video 341 is running ...
# Video 342 is running ...
# Video 343 is running ...
# Video 344 is running ...
# Video 345 is running ...
# Video 346 is running ...
# Video 347 is running ...
# Video 348 is running ...
# Video 349 is running ...
# Video 350 is running ...
# Video 351 is running ...
# Video 352 is running ...
# Video 353 is running ...
# Video 354 is running ...
# Video 355 is running ...
# Video 356 is running ...
# Video 357 is running ...
# Video 358 is running ...
# Video 359 is running ...
# Video 360 is running ...
# Video 361 is running ...
# Video 362 is running ...
# Video 363 is running ...
# Video 364 is running ...
# Video 365 is running ...
# Video 366 is running ...
# Video 367 is running ...
# Video 368 is running ...
# Video 369 is running ...
# Video 370 is running ...
# Video 371 is running ...
# Video 372 is running ...
# Video 373 is running ...
# Video 374 is running ...
# Video 375 is running ...
# Video 376 is running ...
# Video 377 is running ...
# Video 378 is running ...
# Video 379 is running ...
# Video 380 is running ...
# Video 381 is running ...
# Video 382 is running ...
# Video 383 is running ...
# Video 384 is running ...
# Video 385 is running ...
# Video 386 is running ...
# Video 387 is running ...
# Video 388 is running ...
# Video 389 is running ...
# Video 390 is running ...
# Video 391 is running ...
# Video 392 is running ...
# Video 393 is running ...
# Video 394 is running ...
# Video 395 is running ...
# Video 396 is running ...
# Video 397 is running ...
# Video 398 is running ...
# Video 399 is running ...
# Video 400 is running ...
# Video 401 is running ...
# Video 402 is running ...
# Video 403 is running ...
# Video 404 is running ...
# Video 405 is running ...
# Video 406 is running ...
# Video 407 is running ...
# Video 408 is running ...
# Video 409 is running ...
# Video 410 is running ...
# Video 411 is running ...
# Video 412 is running ...
# Video 413 is running ...
# Video 414 is running ...
# Video 415 is running ...
# Video 416 is running ...
# Video 417 is running ...
# Video 418 is running ...
# Video 419 is running ...
# Video 420 is running ...
# Video 421 is running ...
# Video 422 is running ...
# Video 423 is running ...
# Video 424 is running ...
# Video 425 is running ...
# Video 426 is running ...
# Video 427 is running ...
# Video 428 is running ...
# Video 429 is running ...
# Video 430 is running ...
# Video 431 is running ...
# Video 432 is running ...
# Video 433 is running ...
# Video 434 is running ...
# Video 435 is running ...
# Video 436 is running ...
# Video 437 is running ...
# Video 438 is running ...
# Video 439 is running ...
# Video 440 is running ...
# Video 441 is running ...
# Video 442 is running ...
# Video 443 is running ...
# Video 444 is running ...
# Video 445 is running ...
# Video 446 is running ...
# Video 447 is running ...
# Video 448 is running ...
# Video 449 is running ...
# Video 450 is running ...
# Video 451 is running ...
# Video 452 is running ...
# Video 453 is running ...
# Video 454 is running ...
# Video 455 is running ...
# Video 456 is running ...
# Video 457 is running ...
# Video 458 is running ...
# Video 459 is running ...
# Video 460 is running ...
# Video 461 is running ...
# Video 462 is running ...
# Video 463 is running ...
# Video 464 is running ...
# Video 465 is running ...
# Video 466 is running ...
# Video 467 is running ...
# Video 468 is running ...
# Video 469 is running ...
# Video 470 is running ...
# Video 471 is running ...
# Video 472 is running ...
# Video 473 is running ...
# Video 474 is running ...
# Video 475 is running ...
# Video 476 is running ...
# Video 477 is running ...
# Video 478 is running ...
# Video 479 is running ...
# Video 480 is running ...
# Video 481 is running ...
# Video 482 is running ...
# Video 483 is running ...
# Video 484 is running ...
# Video 485 is running ...
# Video 486 is running ...
# Video 487 is running ...
# Video 488 is running ...
# Video 489 is running ...
# Video 490 is running ...
# Video 491 is running ...
# Video 492 is running ...
# Video 493 is running ...
# Video 494 is running ...
# Video 495 is running ...
# Video 496 is running ...
# Video 497 is running ...
# Video 498 is running ...
# Video 499 is running ...
# Video 500 is running ...
# Video 501 is running ...
# Video 502 is running ...
# Video 503 is running ...
# Video 504 is running ...
# Video 505 is running ...
# Video 506 is running ...
# Video 507 is running ...
# Video 508 is running ...
# Video 509 is running ...
# Video 510 is running ...
# Video 511 is running ...
# Video 512 is running ...
# Video 513 is running ...
# Video 514 is running ...
# Video 515 is running ...
# Video 516 is running ...
# Video 517 is running ...
# Video 518 is running ...
# Video 519 is running ...
# Video 520 is running ...
# Video 521 is running ...
# Video 522 is running ...
# Video 523 is running ...
# Video 524 is running ...
# Video 525 is running ...
# Video 526 is running ...
# Video 527 is running ...
# Video 528 is running ...
# Video 529 is running ...
# Video 530 is running ...
# Video 531 is running ...
# Video 532 is running ...
# Video 533 is running ...
# Video 534 is running ...
# Video 535 is running ...
# Video 536 is running ...
# Video 537 is running ...
# Video 538 is running ...
# Video 539 is running ...
# Video 540 is running ...
# Video 541 is running ...
# Video 542 is running ...
# Video 543 is running ...
# Video 544 is running ...
# Video 545 is running ...
# Video 546 is running ...
# Video 547 is running ...
# Video 548 is running ...
# Video 549 is running ...
# Video 550 is running ...
# Video 551 is running ...
# Video 552 is running ...
# Video 553 is running ...
# Video 554 is running ...
# Video 555 is running ...
# Video 556 is running ...
# Video 557 is running ...
# Video 558 is running ...
# Video 559 is running ...
# Video 560 is running ...
# Video 561 is running ...
# Video 562 is running ...
# Video 563 is running ...
# Video 564 is running ...
# Video 565 is running ...
# Video 566 is running ...
# Video 567 is running ...
# Video 568 is running ...
# Video 569 is running ...
# Video 570 is running ...
# Video 571 is running ...
# Video 572 is running ...
# Video 573 is running ...
# Video 574 is running ...
# Video 575 is running ...
# Video 576 is running ...
# Video 577 is running ...
# Video 578 is running ...
# Video 579 is running ...
# Video 580 is running ...
# Video 581 is running ...
# Video 582 is running ...
# Video 583 is running ...
# Video 584 is running ...
# Video 585 is running ...
# Video 586 is running ...
# Video 587 is running ...
# Video 588 is running ...
# Video 589 is running ...
# Video 590 is running ...
# Video 591 is running ...
# Video 592 is running ...
# Video 593 is running ...
# Video 594 is running ...
# Video 595 is running ...
# Video 596 is running ...
# Video 597 is running ...
# Video 598 is running ...
# Video 599 is running ...
# Video 600 is running ...
# Video 601 is running ...
# Video 602 is running ...
# Video 603 is running ...
# Video 604 is running ...
# Video 605 is running ...
# Video 606 is running ...
# Video 607 is running ...
# Video 608 is running ...
# Video 609 is running ...
# Video 610 is running ...
# Video 611 is running ...
# Video 612 is running ...
# Video 613 is running ...
# Video 614 is running ...
# Video 615 is running ...
# Video 616 is running ...
# Video 617 is running ...
# Video 618 is running ...
# Video 619 is running ...
# Video 620 is running ...
# Video 621 is running ...
# Video 622 is running ...
# Video 623 is running ...
# Video 624 is running ...
# Video 625 is running ...
# Video 626 is running ...
# Video 627 is running ...
# Video 628 is running ...
# Video 629 is running ...
# Video 630 is running ...
# Video 631 is running ...
# Video 632 is running ...
# Video 633 is running ...
# Video 634 is running ...
# Video 635 is running ...
# Video 636 is running ...
# Video 637 is running ...
# Video 638 is running ...
# Video 639 is running ...
# Running log has been saved here: ./data_picture_allframe/C3/log.txt
# Running time is: 1:24:42.559627
# /home/xuenhui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
import os
import cv2
import time
import datetime

def framing():
    input_path = './data/C1'
    output_path = './data_picture/C1'
    txt_path = output_path+'/log.txt'
    with open(txt_path, "a", encoding="utf-8") as fi:
        fi.write('\n AllVideosFullName \t Index \t Frame \t Picture\n')

    videos = os.listdir(input_path)
    videos.sort(key = lambda x: x[:-4])

    if len(videos) != 0:
        video_num = 0
        for each_video in videos:
            print('Video {} is running ...'.format(video_num))
            each_video_input = input_path+'/'+str(each_video)
            each_video_output_path = output_path+'/'+str(each_video[:-4])
            if not os.path.exists(each_video_output_path):
                os.mkdir(each_video_output_path)
            
            capture = cv2.VideoCapture(each_video_input)
            if capture.isOpened():
                real = True
            else:
                real = False

            frame_step = 1
            frame_num = 0
            picture_num = 0

            while real:
                real, frame = capture.read()
                if frame is None:
                    break
                else:
                    if(frame_num % frame_step == 0):
                        cv2.imwrite(each_video_output_path+'/'+str(each_video[:-4])+'_Frame'+str(frame_num)+'_Pic'+str(picture_num)+'.jpg',frame)
                        picture_num += 1
                    frame_num += 1
                    cv2.waitKey(1)

            video_num += 1
            with open(txt_path, "a", encoding="utf-8") as fi:
                fi.write('{} \t {} \t {} \t {}\n'.format(each_video[:-4], video_num, frame_num, picture_num ))
            capture.release()

        print('Running log has been saved here: '+txt_path)

    else:
        print('Empty Directory')


if __name__ == '__main__':
    start_time = time.clock()
    framing()
    end_time = time.clock()
    delta_time = datetime.timedelta(seconds = (end_time-start_time))
    print('Running time is: %s '%(delta_time))
# Out:
# Video 0 is running ...
# /home/xuenhui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# Video 1 is running ...
# Video 2 is running ...
# Video 3 is running ...
# Video 4 is running ...
# Video 5 is running ...
# Video 6 is running ...
# Video 7 is running ...
# Video 8 is running ...
# Video 9 is running ...
# Video 10 is running ...
# Video 11 is running ...
# Video 12 is running ...
# Video 13 is running ...
# Video 14 is running ...
# Video 15 is running ...
# Video 16 is running ...
# Video 17 is running ...
# Video 18 is running ...
# Video 19 is running ...
# Video 20 is running ...
# Video 21 is running ...
# Video 22 is running ...
# Video 23 is running ...
# Video 24 is running ...
# Video 25 is running ...
# Video 26 is running ...
# Video 27 is running ...
# Video 28 is running ...
# Video 29 is running ...
# Video 30 is running ...
# Video 31 is running ...
# Video 32 is running ...
# Video 33 is running ...
# Video 34 is running ...
# Video 35 is running ...
# Video 36 is running ...
# Video 37 is running ...
# Video 38 is running ...
# Video 39 is running ...
# Video 40 is running ...
# Video 41 is running ...
# Video 42 is running ...
# Video 43 is running ...
# Video 44 is running ...
# Video 45 is running ...
# Video 46 is running ...
# Video 47 is running ...
# Video 48 is running ...
# Video 49 is running ...
# Video 50 is running ...
# Video 51 is running ...
# Video 52 is running ...
# Video 53 is running ...
# Video 54 is running ...
# Video 55 is running ...
# Video 56 is running ...
# Video 57 is running ...
# Video 58 is running ...
# Video 59 is running ...
# Video 60 is running ...
# Video 61 is running ...
# Video 62 is running ...
# Video 63 is running ...
# Video 64 is running ...
# Video 65 is running ...
# Video 66 is running ...
# Video 67 is running ...
# Video 68 is running ...
# Video 69 is running ...
# Video 70 is running ...
# Video 71 is running ...
# Video 72 is running ...
# Video 73 is running ...
# Video 74 is running ...
# Video 75 is running ...
# Video 76 is running ...
# Video 77 is running ...
# Video 78 is running ...
# Video 79 is running ...
# Video 80 is running ...
# Video 81 is running ...
# Video 82 is running ...
# Video 83 is running ...
# Video 84 is running ...
# Video 85 is running ...
# Video 86 is running ...
# Video 87 is running ...
# Video 88 is running ...
# Video 89 is running ...
# Video 90 is running ...
# Video 91 is running ...
# Video 92 is running ...
# Video 93 is running ...
# Video 94 is running ...
# Video 95 is running ...
# Video 96 is running ...
# Video 97 is running ...
# Video 98 is running ...
# Video 99 is running ...
# Video 100 is running ...
# Video 101 is running ...
# Video 102 is running ...
# Video 103 is running ...
# Video 104 is running ...
# Video 105 is running ...
# Video 106 is running ...
# Video 107 is running ...
# Video 108 is running ...
# Video 109 is running ...
# Video 110 is running ...
# Video 111 is running ...
# Video 112 is running ...
# Video 113 is running ...
# Video 114 is running ...
# Video 115 is running ...
# Video 116 is running ...
# Video 117 is running ...
# Video 118 is running ...
# Video 119 is running ...
# Video 120 is running ...
# Video 121 is running ...
# Video 122 is running ...
# Video 123 is running ...
# Video 124 is running ...
# Video 125 is running ...
# Video 126 is running ...
# Video 127 is running ...
# Video 128 is running ...
# Video 129 is running ...
# Video 130 is running ...
# Video 131 is running ...
# Video 132 is running ...
# Video 133 is running ...
# Video 134 is running ...
# Video 135 is running ...
# Video 136 is running ...
# Video 137 is running ...
# Video 138 is running ...
# Video 139 is running ...
# Video 140 is running ...
# Video 141 is running ...
# Video 142 is running ...
# Video 143 is running ...
# Video 144 is running ...
# Video 145 is running ...
# Video 146 is running ...
# Video 147 is running ...
# Video 148 is running ...
# Video 149 is running ...
# Video 150 is running ...
# Video 151 is running ...
# Video 152 is running ...
# Video 153 is running ...
# Video 154 is running ...
# Video 155 is running ...
# Video 156 is running ...
# Video 157 is running ...
# Video 158 is running ...
# Video 159 is running ...
# Video 160 is running ...
# Video 161 is running ...
# Video 162 is running ...
# Video 163 is running ...
# Video 164 is running ...
# Video 165 is running ...
# Video 166 is running ...
# Video 167 is running ...
# Video 168 is running ...
# Video 169 is running ...
# Video 170 is running ...
# Video 171 is running ...
# Video 172 is running ...
# Video 173 is running ...
# Video 174 is running ...
# Video 175 is running ...
# Video 176 is running ...
# Video 177 is running ...
# Video 178 is running ...
# Video 179 is running ...
# Video 180 is running ...
# Video 181 is running ...
# Video 182 is running ...
# Video 183 is running ...
# Video 184 is running ...
# Video 185 is running ...
# Video 186 is running ...
# Video 187 is running ...
# Video 188 is running ...
# Video 189 is running ...
# Video 190 is running ...
# Video 191 is running ...
# Video 192 is running ...
# Video 193 is running ...
# Video 194 is running ...
# Video 195 is running ...
# Video 196 is running ...
# Video 197 is running ...
# Video 198 is running ...
# Video 199 is running ...
# Video 200 is running ...
# Video 201 is running ...
# Video 202 is running ...
# Video 203 is running ...
# Video 204 is running ...
# Video 205 is running ...
# Video 206 is running ...
# Video 207 is running ...
# Video 208 is running ...
# Video 209 is running ...
# Video 210 is running ...
# Video 211 is running ...
# Video 212 is running ...
# Video 213 is running ...
# Video 214 is running ...
# Video 215 is running ...
# Video 216 is running ...
# Video 217 is running ...
# Video 218 is running ...
# Video 219 is running ...
# Video 220 is running ...
# Video 221 is running ...
# Video 222 is running ...
# Video 223 is running ...
# Video 224 is running ...
# Video 225 is running ...
# Video 226 is running ...
# Video 227 is running ...
# Video 228 is running ...
# Video 229 is running ...
# Video 230 is running ...
# Video 231 is running ...
# Video 232 is running ...
# Video 233 is running ...
# Video 234 is running ...
# Video 235 is running ...
# Video 236 is running ...
# Video 237 is running ...
# Video 238 is running ...
# Video 239 is running ...
# Running log has been saved here: ./data_picture_allframe/C1/log.txt
# Running time is: 0:31:56.425516
# /home/xuenhui/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
import os
import cv2
import time
import datetime

def framing():
    input_path = './data/C2'
    output_path = './data_picture/C2'
    txt_path = output_path+'/log.txt'
    with open(txt_path, "a", encoding="utf-8") as fi:
        fi.write('\n AllVideosFullName \t Index \t Frame \t Picture\n')

    videos = os.listdir(input_path)
    videos.sort(key = lambda x: x[:-4])

    if len(videos) != 0:
        video_num = 0
        for each_video in videos:
            print('Video {} is running ...'.format(video_num))
            each_video_input = input_path+'/'+str(each_video)
            each_video_output_path = output_path+'/'+str(each_video[:-4])
            if not os.path.exists(each_video_output_path):
                os.mkdir(each_video_output_path)
            
            capture = cv2.VideoCapture(each_video_input)
            if capture.isOpened():
                real = True
            else:
                real = False

            frame_step = 1
            frame_num = 0
            picture_num = 0

            while real:
                real, frame = capture.read()
                if frame is None:
                    break
                else:
                    if(frame_num % frame_step == 0):
                        cv2.imwrite(each_video_output_path+'/'+str(each_video[:-4])+'_Frame'+str(frame_num)+'_Pic'+str(picture_num)+'.jpg',frame)
                        picture_num += 1
                    frame_num += 1
                    cv2.waitKey(1)

            video_num += 1
            with open(txt_path, "a", encoding="utf-8") as fi:
                fi.write('{} \t {} \t {} \t {}\n'.format(each_video[:-4], video_num, frame_num, picture_num ))
            capture.release()

        print('Running log has been saved here: '+txt_path)

    else:
        print('Empty Directory')


if __name__ == '__main__':
    start_time = time.clock()
    framing()
    end_time = time.clock()
    delta_time = datetime.timedelta(seconds = (end_time-start_time))
    print('Running time is: %s '%(delta_time))
